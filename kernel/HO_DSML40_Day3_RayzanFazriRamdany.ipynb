# %% [markdown]
# # input

# %%
input()
# Out:
# 12
# '12'

# %%
teks = input()
# Out:
# 12

# %%
print(teks)
# Out:
# 12

# %%
type(teks)
# Out:
# str

# %%
Ini_variable = 'iya ini variable'
print(Ini_variable)
# Out:
# iya ini variable

# %%
angka = input()
# Out:
# 12

# %%
type(angka)
# Out:
# str

# %%
angka_int = int(input())
# Out:
# 12

# %%
type(angka_int)
# Out:
# int

# %%
angka_float = float(input())
# Out:
# 12

# %%
angka1 = 10
angka2 = 2

# %%
angka1 + angka2
# Out:
# 12

# %%
total_jumlah = angka1 + angka2
total_jumlah
# Out:
# 12

# %%
angka1 = '10'
angka2 = '2'
angka1 + angka2
# Out:
# '102'

# %%
angka1 = 10
angka2 = 2
angka1 - angka2
# Out:
# 8

# %%
angka1 / angka2
# Out:
# 5.0

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/summer-products-with-rating-and-performance_2020-08.csv')
df.head()
# Out:
#                                                title  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2  2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3  Hot Summer Cool T-shirt pour les femmes Mode T...
# 4  Femmes Shorts d'été à lacets taille élastique ...
#
#                                           title_orig  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1   Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2  2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3  Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4  Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#   currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# 0            EUR         100               0    3.76            54
# ...

# %%
import seaborn as sns

sns.boxplot(x=df['units_sold']);

# %%
nilai = 76

if nilai > 90:
  print('nilai kamu A')
else:
  print('kasian deh')

if nilai >= 70:
  print('nilai kamu b')
else:
  print('kasian deh')
# Out:
# kasian deh
# nilai kamu b

# %%
if nilai > 90:
  print('nilai kamu A')
elif nilai >= 70:
  print('nilai Kamu B')
else:
  print('kasian deh logic')
# Out:
# nilai Kamu B

# %%
nilai = 31

if nilai > 90:
  print("Nilai kamu A")

elif nilai >= 70:
  print("Nilai kamu B")
elif nilai >= 60:
  print("Nilai kamu C")
elif nilai >= 50:
  print("Nilai kamu D")
elif nilai >= 40:
  print("Nilai kamu E")
elif nilai >= 30:
  print("Nilai kamu F")
else:
  print('kasian deh')
# Out:
# Nilai kamu F

# %%
nilai = 45

if nilai > 90:
  print("Nilai kamu A")
elif nilai >= 70:
  print("Nilai kamu B")
elif nilai >= 60:
  print("Nilai kamu C")
elif nilai >= 50:
  print("Nilai kamu D")
elif nilai >= 40:
  if nilai >= 45:
    print("Nilai kamu E+")
  else:
    print("Nilai kamu E")
elif nilai >= 30:
  print("Nilai kamu F")
else:
  print('kasian deh')
# Out:
# Nilai kamu E+

# %%
def nama_fungsi():
  return None
nama_fungsi()

# %%
def hit_lpersegi(panjang, lebar):
  luas = panjang * lebar
  return luas

# %%
#ppanang 1

panjang = 10
lebar = 5
luas_perpanjang= panjang * lebar
luas_perpanjang
# Out:
# 50

# %%
#ppanang 2

panjang = 20
lebar = 6
luas_perpanjang= panjang * lebar
luas_perpanjang
# Out:
# 120

# %%
#ppanang 3

panjang = 40
lebar = 3
luas_perpanjang= panjang * lebar
luas_perpanjang
# Out:
# 120

# %%
hit_lpersegi(10,5)
# Out:
# 50

# %%
kandidat_loop = [1,2,3,5,6]

for i in kandidat_loop:
  print(i)
# Out:
# 1
# 2
# 3
# 5
# 6
